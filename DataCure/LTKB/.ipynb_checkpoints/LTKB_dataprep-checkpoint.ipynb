# %% [markdown]
# # Data curation for the LTKB dataset
#
# Author: Tim Dudgeon (tdudgeon@informaticsmatters.com)
# This notebook illustrates approaches to preparing a dataset for use in generating predictive models.
# It uses the LTKB dataset from the FDA. __TODO__: specify the source of this.
#
# This dataset contains a significant number of "unfriendly" molecules, some that are proteins and so do not have a SMILES string specified, some that are huge in size, and some that have salts present. This makes it necessary to clean up the data and create a sub-set that is suitable as input for machine learning.

# %%
from IPython.display import Image
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from IPython.display import Image

# %%
from rdkit.Chem import PandasTools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
PandasTools.molRepresentation='svg'

# %%
# read the data from the CSV file
df = pd.read_csv('ltkb.csv', sep=',')
df.dtypes
# Out:
# LTKBID                             object
# PubChem_CID                       float64
# LabelCompoundName                  object
# ApprovalYear                      float64
# DILIConcern                        object
# SeverityClass                       int64
# LabelSection                       object
# AdjudicatedDILI                    object
# vDILIConcern                       object
# Greene_Annotation                  object
# Sakatis_Annotation                 object
# Xu_Annotation                      object
# Zhu_Annotation                     object
# SMILES                             object
# URL (accessed on 1/21/2016)        object
# VER_DISP (1=LTKB-BD, 2=others)      int64
# dtype: object

# %%
# remove unnecessary columns and provide better column names
df.drop('URL (accessed on 1/21/2016)', axis=1, inplace=True)
df.rename({'VER_DISP (1=LTKB-BD, 2=others)':'VER_DISP'}, axis='columns', inplace=True)
df.dropna(subset=['SMILES', 'LTKBID'], how='any', inplace=True)
df.dtypes
# Out:
# LTKBID                 object
# PubChem_CID           float64
# LabelCompoundName      object
# ApprovalYear          float64
# DILIConcern            object
# SeverityClass           int64
# LabelSection           object
# AdjudicatedDILI        object
# vDILIConcern           object
# Greene_Annotation      object
# Sakatis_Annotation     object
# Xu_Annotation          object
# Zhu_Annotation         object
# SMILES                 object
# VER_DISP                int64
# dtype: object

# %%
df.head()
# Out:
#     LTKBID  PubChem_CID LabelCompoundName  ApprovalYear        DILIConcern  SeverityClass              LabelSection AdjudicatedDILI        vDILIConcern Greene_Annotation Sakatis_Annotation Xu_Annotation Zhu_Annotation                                                                                   SMILES  VER_DISP
# 0  LT01185    5361919.0       ceftriaxone        1984.0  Less-DILI-Concern              4         Adverse reactions             Yes  vLess-DILI-Concern                HH    non-hepatotixic      Positive        Postive  CN1C(=NC(=O)C(=O)N1)SCC2=C(N3[C@@H]([C@@H](C3=O)NC(=O)/C(=N/OC)/C4=CSC(=N4)N)SC2)C(=O)O         2
# 1  LT01842       5578.0      trimethoprim        1980.0  Less-DILI-Concern              4         Adverse reactions             Yes  vLess-DILI-Concern                HH    non-hepatotixic      Positive        Postive                                                    COC1=CC(=CC(=C1OC)OC)CC2=CN=C(N=C2N)N         2
# 2  LT00036    5353990.0      tetracycline        1953.0  Less-DILI-Concern              2  Warnings and precautions             Yes  vLess-DILI-Concern                HH        Hepatotoxic      Positive        Postive                 CC1(C2CC3C(C(=O)/C(=C(\N)/O)/C(=O)C3(C(=O)C2=C(C4=C1C=CC=C4O)O)O)N(C)C)O         1
# 3  LT00289       2955.0           dapsone        1979.0  Less-DILI-Concern              3  Warnings and precautions             Yes  vLess-DILI-Concern                HH        Hepatotoxic      Positive        Postive                                                    C1=CC(=CC=C1N)S(=O)(=O)C2=CC=C(C=C2)N         2
# 4  LT00166       1046.0      pyrazinamide        1971.0  Less-DILI-Concern              3  Warnings and precautions             Yes  vLess-DILI-Concern                HH        Hepatotoxic      Positive        Postive                                                                      C1=CN=C(C=N1)C(=O)N         1

# %%
df.shape
# Out:
# (960, 16)

# %% [markdown]
# These molecules are pretty nasty. They have multiple fragments, and some of them are huge.
# We need to clean this up, so start by standardizing the molecucles. This converts them into a "standard" representation, selects the biggest fragment (e.g. removes counter ions and solvents) and neutralises the molecule.

# %%
from rdkit.Chem.MolStandardize import rdMolStandardize

uncharger = rdMolStandardize.Uncharger()

# define the standardize function
def standardize(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        mol = rdMolStandardize.FragmentParent(mol)
        mol = uncharger.uncharge(mol)
    return mol

# apply standardization and add the molecules to the data frame
df['MOL'] = df['SMILES'].apply(standardize)
# Out:
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: COc1cc2c(cc1OC)C1CC(=O)C(CC(C)C)CN1CC2
# RDKit INFO: [12:07:03] New largest fragment: COc1cc2c(cc1OC)C1CC(=O)C(CC(C)C)CN1CC2 (50)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: CC(=O)CCCCn1c(=O)c2c(ncn2C)n(C)c1=O
# RDKit INFO: [12:07:03] New largest fragment: CC(=O)CCCCn1c(=O)c2c(ncn2C)n(C)c1=O (38)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: CN1C(CSCC(F)(F)F)Nc2cc(Cl)c(S(N)(=O)=O)cc2S1(=O)=O
# RDKit INFO: [12:07:03] New largest fragment: CN1C(CSCC(F)(F)F)Nc2cc(Cl)c(S(N)(=O)=O)cc2S1(=O)=O (38)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: CN1CCN(C2=Nc3ccccc3Oc3ccc(Cl)cc32)CC1
# RDKit INFO: [12:07:03] New largest fragment: CN1CCN(C2=Nc3ccccc3Oc3ccc(Cl)cc32)CC1 (41)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: CC(CN(C)C)CN1c2ccccc2CCc2ccccc21
# RDKit INFO: [12:07:03] New largest fragment: CC(CN(C)C)CN1c2ccccc2CCc2ccccc21 (48)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: CN1CCC[C@@H]1Cc1c[nH]c2ccc(CCS(=O)(=O)c3ccccc3)cc12
# RDKit INFO: [12:07:03] New largest fragment: CN1CCC[C@@H]1Cc1c[nH]c2ccc(CCS(=O)(=O)c3ccccc3)cc12 (53)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: C/C(=C\c1csc(C)n1)[C@@H]1C[C@@H]2O[C@]2(C)CCC[C@H](C)[C@H](O)[C@@H](C)C(=O)C(C)(C)[C@@H](O)CC(=O)N1
# RDKit INFO: [12:07:03] New largest fragment: C/C(=C\c1csc(C)n1)[C@@H]1C[C@@H]2O[C@]2(C)CCC[C@H](C)[C@H](O)[C@@H](C)C(=O)C(C)(C)[C@@H](O)CC(=O)N1 (77)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: CCOC(=O)C1=C[C@@H](OC(CC)CC)[C@H](NC(C)=O)[C@@H](N)C1
# RDKit INFO: [12:07:03] New largest fragment: CCOC(=O)C1=C[C@@H](OC(CC)CC)[C@H](NC(C)=O)[C@@H](N)C1 (50)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: O=C(O)CCCc1ccccc1
# RDKit INFO: [12:07:03] New largest fragment: O=C(O)CCCc1ccccc1 (24)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:07:03] Initializing MetalDisconnector
# RDKit INFO: [12:07:03] Running MetalDisconnector
# RDKit INFO: [12:07:03] Initializing Normalizer
# RDKit INFO: [12:07:03] Running Normalizer
# RDKit INFO: [12:07:03] Running LargestFragmentChooser
# RDKit INFO: [12:07:03] Fragment: CCCCCCCCCC(=O)OC1(c2ccc(Cl)cc2)CCN(CCCC(=O)c2ccc(F)cc2)CC1
# RDKit INFO: [12:07:03] New largest fragment: CCCCCCCCCC(=O)OC1(c2ccc(Cl)cc2)CCN(CCCC(=O)c2ccc(F)cc2)CC1 (78)
# RDKit INFO: [12:07:03] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CO/N=C(/C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(CSc3nc(=O)c(=O)[nH]n3C)CS[C@H]12)c1csc(N)n1
# RDKit INFO: [12:11:36] New largest fragment: CO/N=C(/C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(CSc3nc(=O)c(=O)[nH]n3C)CS[C@H]12)c1csc(N)n1 (54)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC
# RDKit INFO: [12:11:36] New largest fragment: COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC (39)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CN(C)C1C(=O)/C(=C(\N)O)C(=O)C2(O)C(=O)C3=C(O)c4c(O)cccc4C(C)(O)C3CC12
# RDKit INFO: [12:11:36] New largest fragment: CN(C)C1C(=O)/C(=C(\N)O)C(=O)C2(O)C(=O)C3=C(O)c4c(O)cccc4C(C)(O)C3CC12 (56)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1
# RDKit INFO: [12:11:36] New largest fragment: Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1 (29)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: NC(=O)c1cnccn1
# RDKit INFO: [12:11:36] New largest fragment: NC(=O)c1cnccn1 (14)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CC(C)OC(=O)C(C)(C)Oc1ccc(C(=O)c2ccc(Cl)cc2)cc1
# RDKit INFO: [12:11:36] New largest fragment: CC(C)OC(=O)C(C)(C)Oc1ccc(C(=O)c2ccc(Cl)cc2)cc1 (46)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: O=P1(N(CCCl)CCCl)NCCCO1
# RDKit INFO: [12:11:36] New largest fragment: O=P1(N(CCCl)CCCl)NCCCO1 (29)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21
# RDKit INFO: [12:11:36] New largest fragment: CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21 (40)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)(C(=O)CO)C[C@@H]3O[C@H]1C[C@H](N)[C@H](O)[C@H](C)O1
# RDKit INFO: [12:11:36] New largest fragment: COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)(C(=O)CO)C[C@@H]3O[C@H]1C[C@H](N)[C@H](O)[C@H](C)O1 (68)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CCC[C@@H]1C[C@@H](C(=O)NC(C(C)Cl)[C@H]2O[C@H](SC)[C@H](O)[C@@H](O)[C@H]2O)N(C)C1
# RDKit INFO: [12:11:36] New largest fragment: CCC[C@@H]1C[C@@H](C(=O)NC(C(C)Cl)[C@H]2O[C@H](SC)[C@H](O)[C@@H](O)[C@H]2O)N(C)C1 (60)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1
# RDKit INFO: [12:11:36] New largest fragment: CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1 (30)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1
# RDKit INFO: [12:11:36] New largest fragment: O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1 (37)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment:
C1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccccc3)C(=O)N2[C@H]1C(=O)O (43)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: Cc1cc(C)cc(OCC2CNC(=O)O2)c1
# RDKit INFO: [12:11:36] New largest fragment: Cc1cc(C)cc(OCC2CNC(=O)O2)c1 (31)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CC(=O)NCCCS(=O)(=O)O
# RDKit INFO: [12:11:36] New largest fragment: CC(=O)NCCCS(=O)(=O)O (22)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: COC(=O)[C@H](c1ccccc1Cl)N1CCc2sccc2C1
# RDKit INFO: [12:11:36] New largest fragment: COC(=O)[C@H](c1ccccc1Cl)N1CCc2sccc2C1 (37)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: O=C1CN=C(c2ccccc2Cl)c2cc([N+](=O)[O-])ccc2N1
# RDKit INFO: [12:11:36] New largest fragment: O=C1CN=C(c2ccccc2Cl)c2cc([N+](=O)[O-])ccc2N1 (32)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C
# RDKit INFO: [12:11:36] New largest fragment: CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C (53)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1
# RDKit INFO: [12:11:36] New largest fragment: CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1 (53)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1
# RDKit INFO: [12:11:36] New largest fragment: CCOC(=O)C(C)(C)Oc1ccc(Cl)cc1 (31)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: COC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1ccccc1[N+](=O)[O-]
# RDKit INFO: [12:11:36] New largest fragment: COC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1ccccc1[N+](=O)[O-] (43)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: CN1/C(=C(/O)Nc2ccccn2)C(=O)c2ccccc2S1(=O)=O
# RDKit INFO: [12:11:36] New largest fragment: CN1/C(=C(/O)Nc2ccccn2)C(=O)c2ccccc2S1(=O)=O (36)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12
# RDKit INFO: [12:11:36] New largest fragment: C=C[C@H]1CN2CC[C@H]1C[C@@H]2[C@@H](O)c1ccnc2ccc(OC)cc12 (48)
# RDKit INFO: [12:11:36] Running Uncharger
# RDKit INFO: [12:11:36] Initializing MetalDisconnector
# RDKit INFO: [12:11:36] Running MetalDisconnector
# RDKit INFO: [12:11:36] Initializing Normalizer
# RDKit INFO: [12:11:36] Running Normalizer
# RDKit INFO: [12:11:36] Running LargestFragmentChooser
# RDKit INFO: [12:11:36] Fragment: COc1cc([C@@H]2c3cc4c(cc3[C@@H](O[C@@H]3O[C@@H]5CO[C@@H](C)O[C@H]5[C@H](O)[C@H]3O)[C@H]3COC(=O)[C@H]23)OCO4)cc(OC)c1O
# RDKit INFO: [12:11:36] New largest fragment: COc1cc([C@@H]2c3cc4c(cc3[C@@H](O[C@@H]3O[C@@H]5CO[C@@H](C)O[C@H]5[C@H](O)[C@H]3O)[C@H]3COC(=O)[C@H]23)OCO4)cc(OC)c1O (74)
# RDKit INFO: [12:11:36] Running Uncharger
# ...
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: CC(C)NCC(O)COc1ccc(CCOCC2CC2)cc1
# RDKit INFO: [12:11:41] New largest fragment: CC(C)NCC(O)COc1ccc(CCOCC2CC2)cc1 (51)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment

# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=CCS[C@H]12)c1csc(N)n1
# RDKit INFO: [12:11:41] New largest fragment: CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=CCS[C@H]12)c1csc(N)n1 (38)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: COc1cc2nc(N3CCN(C(=O)C4COc5ccccc5O4)CC3)nc(N)c2cc1OC
# RDKit INFO: [12:11:41] New largest fragment: COc1cc2nc(N3CCN(C(=O)C4COc5ccccc5O4)CC3)nc(N)c2cc1OC (58)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: C=C(CC)C(=O)c1ccc(OCC(=O)O)c(Cl)c1Cl
# RDKit INFO: [12:11:41] New largest fragment: C=C(CC)C(=O)c1ccc(OCC(=O)O)c(Cl)c1Cl (31)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: Nc1nc(=O)c2ncn(COC(CO)CO)c2[nH]1
# RDKit INFO: [12:11:41] New largest fragment: Nc1nc(=O)c2ncn(COC(CO)CO)c2[nH]1 (31)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: NC(N)=NC(=O)Cc1c(Cl)cccc1Cl
# RDKit INFO: [12:11:41] New largest fragment: NC(N)=NC(=O)Cc1c(Cl)cccc1Cl (24)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: CC1Cc2ccccc2N1NC(=O)c1ccc(Cl)c(S(N)(=O)=O)c1
# RDKit INFO: [12:11:41] New largest fragment: CC1Cc2ccccc2N1NC(=O)c1ccc(Cl)c(S(N)(=O)=O)c1 (40)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: CCC1(c2ccccc2)NC(=O)N(C)C1=O
# RDKit INFO: [12:11:41] New largest fragment: CCC1(c2ccccc2)NC(=O)N(C)C1=O (30)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: O=S(=O)(O)CCS
# RDKit INFO: [12:11:41] New largest fragment: O=S(=O)(O)CCS (13)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: [Cl-]
# RDKit INFO: [12:11:41] New largest fragment: [Cl-] (1)
# RDKit INFO: [12:11:41] Fragment: C=CCNCCCCCCCCCC
# RDKit INFO: [12:11:41] New largest fragment: C=CCNCCCCCCCCCC (41)
# RDKit INFO: [12:11:41] Fragment: C=CCNCCCCCC[N+](C)(C)C
# RDKit INFO: [12:11:41] New largest fragment: C=CCNCCCCCC[N+](C)(C)C (41)
# RDKit INFO: [12:11:41] Fragment: C=CCN
# RDKit INFO: [12:11:41] Fragment: ClCC1CO1
# RDKit INFO: [12:11:41] Fragment: Cl
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: CCOC(=O)[C@H](CCc1ccccc1)N[C@@H](C)C(=O)N1Cc2cc(OC)c(OC)cc2C[C@H]1C(=O)O
# RDKit INFO: [12:11:41] New largest fragment: CCOC(=O)[C@H](CCc1ccccc1)N[C@@H](C)C(=O)N1Cc2cc(OC)c(OC)cc2C[C@H]1C(=O)O (70)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer
# RDKit INFO: [12:11:41] Running LargestFragmentChooser
# RDKit INFO: [12:11:41] Fragment: CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c5c(nc6cc(C)ccn65)c4c3C2=O)NC(=O)/C(C)=C\C=C\[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C
# RDKit INFO: [12:11:41] New largest fragment: CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c5c(nc6cc(C)ccn65)c4c3C2=O)NC(=O)/C(C)=C\C=C\[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C (108)
# RDKit INFO: [12:11:41] Running Uncharger
# RDKit INFO: [12:11:41] Initializing MetalDisconnector
# RDKit INFO: [12:11:41] Running MetalDisconnector
# RDKit INFO: [12:11:41] Initializing Normalizer
# RDKit INFO: [12:11:41] Running Normalizer

# %%
# create categories
df2 = df.astype({
    'DILIConcern':'category',
    'SeverityClass':'category',
    'LabelSection':'category',
    'AdjudicatedDILI':'category',
    'vDILIConcern':'category',
    'Greene_Annotation':'category',
    'Sakatis_Annotation':'category',
    'Xu_Annotation':'category',
    'Zhu_Annotation':'category',
    'VER_DISP':'category'
    })
df2.dtypes
# Out:
# LTKBID                  object
# PubChem_CID            float64
# LabelCompoundName       object
# ApprovalYear           float64
# DILIConcern           category
# SeverityClass         category
# LabelSection          category
# AdjudicatedDILI       category
# vDILIConcern          category
# Greene_Annotation     category
# Sakatis_Annotation    category
# Xu_Annotation         category
# Zhu_Annotation        category
# SMILES                  object
# VER_DISP              category
# MOL                     object
# dtype: object

# %% [markdown]
# Let's inspect the data now. We have a wide range of types of molecules here and it will be best to focus on the main corpus of data and exclude the very quirky molecules as they will not be useful for predictions.
# We'll take a 'drug-likeness' perspective to this, so let's starrt by examining the size of the molecules (as indicated by the heavy atom count) and the cLogP. Also let's count the number of fragments to check that they all have just one now.

# %%
# calculate LogP, heavy atom count and number of fragments
from rdkit.Chem import Descriptors
df2['LOGP'] = df2['MOL'].apply(lambda mol: Descriptors.MolLogP(mol))
df2['HAC'] = df2['MOL'].apply(lambda mol: Descriptors.HeavyAtomCount(mol))
df2['FRAGS'] =  df2['MOL'].apply(lambda mol: len(Chem.GetMolFrags(mol,asMols=True)))

# %%
plt.figure();
df2.plot.scatter(x='LOGP', y='HAC');

# %% [markdown]
# So we have a small number of very large molecules and a small number of molecules with very low cLogP values. Mostly these are the same molecules. Let's look at them.
# Playing around with the filters a bit we conclude that we shoudl exclude mols with a LogP < 14 and HAC > 200.

# %%
nastyMols = df2[df2['LOGP'] < -14]
nastyMols = nastyMols[nastyMols['HAC'] > 200]
nastyMols.shape
# Out:
# (11, 19)

# %%
PandasTools.FrameToGridImage(nastyMols, column='MOL', legendsCol='LOGP', molsPerRow=3, subImgSize=(400, 400))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x1600 at 0x7F4AFC89AE80>

# %%
# so let's get the nice mols
niceMols = df2[df2['LOGP'] >= -14]
niceMols = niceMols[niceMols['HAC'] <= 200]
niceMols.shape
# Out:
# (948, 19)

# %%
PandasTools.FrameToGridImage(niceMols, column='MOL', legendsCol='LTKBID', molsPerRow=4, subImgSize=(400, 400))
# Out:
# /opt/conda/lib/python3.6/site-packages/rdkit/Chem/Draw/IPythonConsole.py:183: UserWarning: Truncating the list of molecules to be displayed to 50. Change the maxMols value to display more.
#   % (maxMols))
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x5200 at 0x7F4AFC5C8400>

# %%
plt.figure();
niceMols.plot.scatter(x='LOGP', y='HAC');

# %% [markdown]
# Now generate Morgan2 and RDKit fingerprints that we can use for machine learning.

# %%
niceMols['RDK5'] = niceMols.MOL.apply(lambda mol: Chem.RDKFingerprint(mol, maxPath=5))
niceMols['MORGAN2'] = niceMols.MOL.apply(lambda mol: AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024))

# %%
# look at the Most DILI mols
mostDili = niceMols[niceMols['DILIConcern'] == 'Most-DILI-Concern']
mostDili.shape
# Out:
# (197, 21)

# %% [markdown]
# These are the Most DILI molecules from our cleaned set.

# %%
PandasTools.FrameToGridImage(mostDili, column='MOL', legendsCol='LTKBID', molsPerRow=4, subImgSize=(300, 300))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x3900 at 0x7F4B1D70CEB8>
