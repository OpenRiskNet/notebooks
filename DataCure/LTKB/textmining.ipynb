# %% [markdown]
# # DataCure Text Mine Workflow
# **Author**: Marc Jacobs
#
# This notebook outlines the implementation of a `search for compound information from the literature`. Workflow :
#
# 1. authenticate
# 1. find proper concept to text mine ( [OLS](https://www.ebi.ac.uk/ols/docs/api), [TeMOwl](http://bart.scai.fraunhofer.de:9090/swagger-ui.html#/) )
# 1. find proper documents containing that concept ( [SCAIView](http://api.scaiview.com) )
# 1. further analyze documents with NLP ( SCAIView -> UIMA )

# %% [markdown]
# ## Notebook Imports

# %%
import simplejson as json
import requests
import urllib
from requests.exceptions import HTTPError
from IPython.core.display import display, HTML
import pandas as pd

# %% [markdown]
# some Fraunhofer specific configurations
#
# > **to be discussed**
# > * which services should be deployed in the ORN infrastructure?
# > * who is the contact there?
# > * where to place the docker files / containers?

# %%
keycloak_uri = 'http://keycloak.scai.fraunhofer.de/auth/realms/SCAI-Bio/'
temowl_uri   = 'http://bart.scai.fraunhofer.de:9090/'
scaiview_uri = 'http://api.scaiview.com/api/'

# %% [markdown]
# ## Step 1 - fetch security token
#
# as a start we use the _keycloak server_ from Fraunhofer SCAI.
#
# > **to be discussed** with the infrastructure team
# > * how to use ORN authentication?
# > * who is the contact there?

# %%
response = requests.post(
    keycloak_uri+'protocol/openid-connect/token', 
    data={'grant_type':'client_credentials', 'client_id':'temowl-backend', 'client_secret':'6f2879cd-0d00-457b-9909-abc78f374d73'}
)

token = response.json()['access_token']
token
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJudnV2UGU2c000TVQyOWFRNkV4dGI5TldoVFJramZWYmcwQTNUVTZNSFpzIn0.....XGAik8AIVP1d6VDRrjmncieTgYdnoaELkWsacfBoqEOqRVkZe2KM1s2N7zhR93nqGTxWJWbLzjefJ_KvC1yqb1jKqaiAKt2yM4WRsLUzB8RBjeH57CcxyEmqSBwb1mZdXLmcQvWhiEfQmGN6Vd1-RDUQsbKCKduJ70rf-1rgGqwqDGGCCl3895pqKe8H1uH3MfU9Bqt2ykwO7dQLyUnM13gUP5hvD5ZyIwhMbAKKUEfwy4uaunkZ0TkBVdj1Xn7SXg2ZyemI4f3UNWr95k2LE1-MvvVNurT4R1gZOyeHPyICwL4QM_VX68iG3GSiF_nYxdexhU2KesaJwPLYiv-wMw'

# %% [markdown]
# ## Step 2 - get concept for Acetaminophen
#
# search for concept of `Acetaminophen` aka `Paracetamol` in `chebi`

# %%
response = requests.get(
    temowl_uri+'terminologies/chebi/concepts/search?',
    params={'exact': 'false', 'q': 'Paracetamol', 'lang': 'en', 'page': '0', 'size': '10'},
    headers={'Accept': 'application/json'},
)

json_response = response.json()
acetaminophen = json_response['content'][0]['conceptID']
acetaminophen
# Out:
# 'chebi:46195'

# %% [markdown]
# got it: `Acetaminophen` is `chebi:46195`.
#
# now retrieve details on `Paracetamol`:

# %%
response = requests.get(
    temowl_uri+'terminologies/chebi/concepts/'+urllib.parse.quote(acetaminophen),
    params={'lang': 'en', 'page': '0', 'size': '10'},
    headers={'Accept': 'application/json'},
)
json_response = response.json()
json_response['description']['description']
# Out:
# 'A member of the class of phenols that is 4-aminophenol in which one of the hydrogens attached to the amino group has been replaced by an acetyl group.'

# %% [markdown]
# fetch some synonyms in order to expand the search query

# %%
response = requests.get(
    temowl_uri+'terminologies/chebi/concepts/'+urllib.parse.quote(acetaminophen)+'/labels',
    params={'lang': 'en', 'page': '0', 'size': '10'},
    headers={'Accept': 'application/json'},
)

full_text_query = '( Acetaminophen'

json_response = response.json()
for synonym in json_response['content']:
    full_text_query += ' OR ' + synonym['name']
    
full_text_query += ' )'
full_text_query
# Out:
# '( Acetaminophen OR Paracetamol OR N-(4-hydroxyphenyl)acetamide OR paracetamol )'

# %% [markdown]
# ## Step 3 - get documents on Acetaminophen
#
# > **to be discussed** - here we are using the different Fraunhofer pre-indexed document collections
# > * which document collections does ToxPlanet have?
# > * how are they indexed and searchable?
# > * how do we access them?
# > * who is the technical contact there?
#
# ### define some helper functions
#
# fetch a pmid and render HTML

# %%
def fetchDocumentAndRenderHTML( pmid, collection ):
   "fetch document with pmid and return HTML"
   response = requests.get(
        scaiview_uri+'v3/fetch/' + urllib.parse.quote(pmid)+'?',
        params={'collection': collection},
        headers={'Accept': 'text/html', 'Authorization': 'Bearer '+token},
   )
   return HTML(response.text)

def fetchDocument( pmid, collection ):
   "fetch document with pmid and return HTML"
   response = requests.get(
        scaiview_uri+'v3/fetch/' + urllib.parse.quote(pmid)+'?',
        params={'collection': collection},
        headers={'Accept': 'application/json', 'Authorization': 'Bearer '+token},
   )
   return response.json()

# %% [markdown]
# search for documents

# %%
def querySCAIView( query, collection, limit = 10 ):
    "fetch a list of documents matching the query, return json"

    encoded_query = urllib.parse.quote(query)
        
    response = requests.get(
        scaiview_uri+'v2/solr/search?',
        params={'q':encoded_query, 'rows':limit, 'sortField':'date', 'sortOrder':'DESC', 'collection':collection},
        headers={'Accept': 'application/json', 'Authorization': 'Bearer '+token},
    )
    
    return response.json()
    

def querySCAIViewAsDocuments( query, collection, limit = 10 ):
    "fetch a list of documents matching the query"
    
    json_response = querySCAIView( query, collection, limit )

    print('{}: {} found'.format(query, json_response['numFound']))
    return json_response['documents']


def querySCAIViewAsPD( query, collection, limit = 10 ):
    "fetch a list of documents matching the query, return as pd"

    json_response =  querySCAIView( query, collection, limit )
    
    documents = json_response['documents']
    numFound = json_response['numFound']
    
    print('{}: {} found'.format(query, numFound))

    df = pd.DataFrame([], columns = ['PMID','Title'])

    for x in range(0, min(len(documents),numFound-1)):
        df = df.append(pd.DataFrame([[documents[x]['id'][5:], documents[x]['title'][0]]], index = [x+1], columns = ['PMID','Title']))

    return df

# %% [markdown]
# ### query for documents for Acetaminophen
#
#
# *recall based* - with free text search

# %%
df = querySCAIViewAsPD(full_text_query + ' AND carcinogen*', 'Medline_2019', 10)
df.sort_values(by=['PMID'], ascending=False)
# Out:
# ( Acetaminophen OR Paracetamol OR N-(4-hydroxyphenyl)acetamide OR paracetamol ) AND carcinogen*: 2287595 found
#         PMID                                              Title
# 3   30640403  [Recurrence and chronicity of major depressive...
# 4   30640402  [Electroconvulsion therapy for persistent depr...
# 2   30572411  The Effect of Lower Transaction Costs on Socia...
# 1   30572410  Immigration Enforcement and Children's Living ...
# 5   30103352  Medication reconciliation and review for older...
# 6   29169162  Application of Electrocautery Needle Knife Com...
# 7   29166637  Assessing Vessel Tone during Coronary Artery S...
# 8   29045949  Effectiveness of a Home-Based Active Video Gam...
# 9   28881352  Current Practice of Airway Stenting in the Adu...
# 10  28864973  The Role of Oxytocin in Social Buffering: What...

# %% [markdown]
# *precision based* - using indexed substances field

# %%
df = querySCAIViewAsPD('Substances:Carcinogens AND Substances:Acetaminophen', 'Medline_2019', 10)
df.sort_values(by=['PMID'], ascending=False)
# Out:
# Substances:Carcinogens AND Substances:Acetaminophen: 146138 found
#         PMID                                              Title
# 5   30589062  Occupational risk perception, stressors and st...
# 3   30568084  [Study on the Establishment of a Specific Simi...
# 8   30288716  Supercooling-Promoting (Anti-ice Nucleation) S...
# 4   30272428  What Interventions Work Best for Families Who ...
# 7   30199073  [Current trends of the choice and processing o...
# 6   30199059  [The in vitro examination of the effectiveness...
# 10  30176634  [Ultramicroscopic features of cells and vessel...
# 9   29895139  Methods for the initial (non-laboratory) asses...
# 2   28466189  A Review of the Environmental Degradation, Eco...
# 1   28444578  Experimental Psychosis Research and Schizophre...

# %% [markdown]
# ### Step 4 - mine full text documents

# %%
documents = querySCAIViewAsDocuments(full_text_query + ' AND carcinogen*', 'PMC_2019', 10)
documents
# Out:
# ( Acetaminophen OR Paracetamol OR N-(4-hydroxyphenyl)acetamide OR paracetamol ) AND carcinogen*: 2031480 found
# [{'id': 'PMCID:PMC6318039',
#   'title': ['Epidemiology of prediabetes and diabetes in Namibia, Africa: a multilevel analysis'],
#   'abstract': ['Diabetes is a leading cause of progressive morbidity and early mortality worldwide. Little is known on the burden of diabetes and pre-diabetes in Namibia, a Sub-Saharan African (SSA) country that is undergoing a demographic transition.We estimated the prevalence and correlates of diabetes (defined as fasting [capillary] blood glucose [FBG]>126 mg/dL) and prediabetes (defined by World Health Organization [WHO] and American Diabetes Association [ADA] criteria [FBG 110–125 mg/dL and 100–125 mg/dL, respectively]) in a random sample of 3278 participants aged 35–64 from the 2013 Namibia Demographic and Health Survey.The prevalence of diabetes was 5.1% (95% Confidence Interval [CI]: 4.2–6.2), with no evidence of gender differences (p=0.45). The prevalence of prediabetes was 6.8% (5.8–8.0) and 20.1% (18.4–21.9) using WHO and ADA criteria, respectively. Male sex, older age, higher body mass index (BMI) and occupation independently increased the odds of diabetes in Namibia, while higher BMI was associated with the higher odds of prediabetes and residing in household categorized as middle wealth index were associated with lower odds of prediabetes (Adjusted odds ratio [aOR] = 0.71; 95% Credible Interval [CrI] = 0.46–0.99). There was significant clustering of prediabetes and diabetes at the community-level.One in five adult Namibians has prediabetes by ADA criteria. Resources should be invested at the community level to promote efforts to prevent progression of this disease and its complications.'],
#   'documentIdentifiers': ['PMID:30058263',
#    'DOI:10.1111/1753-0407.12829',
#    'MANUSCRIPT:NIHMS983556'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'J Diabetes',
#   'source': 'J Diabetes',
#   'authors': ['Victor T. ADEKANMBI',
#    'Olalekan A. UTHMAN',
#    'Sebhat ERQOU',
#    'Justin B. ECHOUFFO-TCHEUGUI',
#    'Meera N. HARHAY',
#    'Michael O. HARHAY'],
#   'language': ['EN'],
#   'date': 1583078512499,
#   '_version_': 1624645317434540032},
#  {'id': 'PMCID:PMC6320322',
#   'title': ['Activities and specificities of CRISPR-Cas9 and Cas12a nucleases for targeted mutagenesis in maize'],
#   'abstract': ['CRISPR-Cas9 and Cas12a (Cpf1) nucleases are two of the most powerful genome editing tools in plants. In this work, we compared their activities by targeting maizeglossy2gene coding region that has overlapping sequences recognized by both nucleases. We introduced constructs carrying SpCas9-guide RNA (gRNA) and LbCas12a-CRISPR RNA (crRNA) into maize inbred B104 embryos usingAgrobacterium-mediated transformation. On-target mutation analysis showed that 90–100% of the Cas9-edited T0 plants carried indel mutations and 63–77% of them were homozygous or biallelic mutants. In contrast, 0–60% of Cas12a-edited T0 plants had on-target mutations. We then conducted CIRCLE-seq analysis to identify genome-wide potential off-target sites for Cas9. A total of 18 and 67 potential off-targets were identified for the two gRNAs, respectively, with an average of five mismatches compared to the target sites. Sequencing analysis of a selected subset of the off-target sites revealed no detectable level of mutations in the T1 plants, which constitutively express Cas9 nuclease and gRNAs. In conclusion, our results suggest that the CRISPR-Cas9 system used in this study is highly efficient and specific for genome editing in maize, while CRISPR-Cas12a needs further optimization for improved editing efficiency.'],
#   'documentIdentifiers': ['PMID:29972722',
#    'DOI:10.1111/pbi.12982',
#    'MANUSCRIPT:NIHMS980267'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'Plant Biotechnol. J.',
#   'source': 'Plant Biotechnol. J.',
#   'authors': ['Keunsub Lee',
#    'Yingxiao Zhang',
#    'Benjamin P. Kleinstiver',
#    'Jimmy A. Guo',
#    'Martin J. Aryee',
#    'Jonah Miller',
#    'Aimee Malzahn',
#    'Scott Zarecor',
#    'Carolyn J. Lawrence-Dill',
#    'J. Keith Joung',
#    'Yiping Qi',
#    'Kan Wang'],
#   'language': ['EN'],
#   'date': 1583078251468,
#   '_version_': 1624645043740475392},
#  {'id': 'PMCID:PMC6311610',
#   'title': ['Understanding the Role of Exercise in Cancer Cachexia Therapy'],
#   'abstract': ['Cachexia, the unintentional loss of body weight, is prevalent in many cancer types, and the associated skeletal muscle mass depletion increases patient morbidity and mortality. While anorexia can be present, cachexia is not reversible with nutritional therapies alone. Pharmacological agents have been proposed to treat this condition, but there are currently no approved treatments. Nonetheless, the hallmark characteristics associated with cancer cachexia remain viable foundations for future therapies. Regular physical activity holds a promising future as a nonpharmacological alternative to improve patient survival through cachexia prevention. Evidence suggests exercise training is beneficial during cancer treatment and survival. However, the mechanistic examination of cachectic skeletal muscle’s response to exercise is both needed and justified. The primary objective of this review is to discuss the role of exercise for the prevention and treatment of cancer-associated muscle wasting. Initially, we provide an overview of systemic alterations induced by cancer and their role in the regulation of wasting processes during cachexia progression. We then discuss how exercise could alter disrupted regulatory pathways related to growth and metabolism during cancer-induced muscle atrophy. Last, we outline current exercise prescription guidelines and how exercise could be a potential behavioral therapy to curtail cachexia development in cancer patients.'],
#   'documentIdentifiers': ['PMID:30627079',
#    'DOI:10.1177/1559827617725283',
#    'MANUSCRIPT:NIHMS908711'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'Am J Lifestyle Med',
#   'source': 'Am J Lifestyle Med',
#   'authors': ['Justin P. Hardee', 'Brittany R. Counts', 'James A. Carson'],
#   'language': ['EN'],
#   'date': 1580572658400,
#   '_version_': 1624645050990329856},
#  {'id': 'PMCID:PMC6312732',
#   'title': ['Human cartilage-derived progenitors resist terminal differentiation and require CXCR4 activation to successfully bridge meniscus tissue tears'],
#   'abstract': ['Meniscus injuries are among the most common orthopaedic injuries. Tears in the inner one-third of the meniscus heal poorly and present a significant clinical challenge. In this study, we hypothesized that progenitor cells from healthy human articular cartilage (C-PCs) may be more suitable than bone-marrow mesenchymal stem cells (BM-MSCs) to mediate bridging and reintegration of fibrocartilage tissue tears in meniscus. C-PCs were isolated from healthy human articular cartilage based on their expression of mesenchymal stem/progenitor marker ALCAM (CD166). Our findings revealed that healthy human C-PCs are CD166+, CD90+, CD54+, CD106- cells with multi-lineage differentiation potential and elevated basal expression of chondrogenesis marker SOX-9. We show that, similar to BM-MSCs, C-PCs are responsive to the chemokine stromal cell derived factor-1 (SDF-1) and they can successfully migrate to the area of meniscal tissue damage promoting collagen bridging across inner meniscal tears. In contrast to BM-MSCs, C-PCs maintaining reduced expression of cellular hypertrophy marker collagen X in monolayer culture and in an ex-plant organ culture model of meniscus repair. Treatment of C-PCs with SDF-1/CXCR4 pathway inhibitor AMD3100 disrupted cell localization to area of injury and prevented meniscus tissue bridging thereby indicating that the SDF-1/CXCR4 axis is an important mediator of this repair process. This study suggests that C-PCs from healthy human cartilage may potentially be a useful tool for fibrocartilage tissue repair/regeneration because they resist cellular hypertrophy and mobilize in response to chemokine signaling.Using an explant model of meniscus repair, we demonstrate that progenitor cells from healthy human articular cartilage resist cellular hypertrophy and mediate meniscal fibrocartilage healing in a manner that is dependent of SDF-1/CXCR4 chemokine signaling.'],
#   'documentIdentifiers': ['PMID:30358021',
#    'DOI:10.1002/stem.2923',
#    'MANUSCRIPT:NIHMS993159'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'Stem Cells',
#   'source': 'Stem Cells',
#   'authors': ['Chathuraka T. Jayasuriya',
#    'John Twomey-Kozak',
#    'Jake Newberry',
#    'Salomi Desai',
#    'Peter Feltman',
#    'Jonathan R. Franco',
#    'Neill Li',
#    'Richard Terek',
#    'Michael G. Ehrlich',
#    'Brett D. Owens'],
#   'language': ['EN'],
#   'date': 1580572303495,
#   '_version_': 1624644678843367424},
#  {'id': 'PMCID:PMC6305793',
#   'title': ['Perivascular Adventitial Fibroblast Specialization Accompanies T Cell Retention in the Inflamed Human Dermis'],
#   'abstract': ['Perivascular accumulation of lymphocytes can be a prominent histopathologic feature of various human inflammatory skin diseases. Select examples include systemic sclerosis, spongiotic dermatitis and cutaneous lupus. While a large body of work has described various aspects of the endothelial and vascular smooth muscle layers in these diseases, the outer adventitial compartment is poorly explored. The goal of the present study was to characterize perivascular adventitial fibroblast states in inflammatory human skin diseases and relate these states to perivascular lymphocyte accumulation. In normal skin, adventitial fibroblasts are distinguished by CD90 expression and dense perivascular lymphocytic infiltrates are uncommon. In systemic sclerosis, this compartment expands, but lymphocyte infiltrates remain sparse. In contrast, perivascular adventitial fibroblast expression of VCAM1 is upregulated in spongiotic dermatitis and lupus and is associated with a dense perivascular T cell infiltrate. VCAM1 expression marks transitioned fibroblasts that show some resemblance to the reticular stromal cells in secondary lymphoid organs. Expanded adventitial compartments with perivascular infiltrates similar to the human settings were not seen in the inflamed murine dermis. This species difference may hinder the dissection of aspects of perivascular adventitial pathology. The altered perivascular adventitial compartment and its associated reticular network form a niche for lymphocytes and appear to be fundamental in the development of an inflammatory pattern.'],
#   'documentIdentifiers': ['PMID:30510068',
#    'DOI:10.4049/jimmunol.1801209',
#    'MANUSCRIPT:NIHMS1511651'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'J. Immunol.',
#   'source': 'J. Immunol.',
#   'authors': ['Alexander M. S. Barron',
#    'Julio C. Mantero',
#    'Jonathan D. Ho',
#    'Banafsheh Nazari',
#    'Katharine L. Horback',
#    'Jag Bhawan',
#    'Robert Lafyatis',
#    'Christina Lam',
#    'Jeffrey L. Browning'],
#   'language': ['EN'],
#   'date': 1580572051111,
#   '_version_': 1624644414228922368},
#  {'id': 'PMCID:PMC6312737',
#   'title': ['BIN1 induces the formation of T-tubules and adult-like Ca2+release units in developing cardiomyocytes'],
#   'abstract': ['Human embryonic stem cell-derived cardiomyocytes (hESC-CMs) are at the center of new cell-based therapies for cardiac disease, but may also serve as a usefulin vitromodel for cardiac cell development. An intriguing feature of hESC-CMs is that although they express contractile proteins and have sarcomeres, they do not develop transverse-tubules (T-tubules) with adult-like Ca2+release units (CRUs). We tested the hypothesis that expression of the protein BIN1 in hESC-CMs promotes T-tubules formation, facilitates CaV1.2 channel clustering along the tubules, and results in the development of stable CRUs. Using electrophysiology, [Ca2+]iimaging, and super resolution microscopy, we found that BIN1 expression induced T-tubule development in hESC-CMs, while increasing differentiation towards a more ventricular-like phenotype. Voltage-gated CaV1.2 channels clustered along the surface sarcolemma and T-tubules of hESC-CM. The length and width of the T-tubules as well as the expression and size of CaV1.2 clusters grew, as BIN1 expression increased and cells matured. BIN1 expression increased CaV1.2 channel activity and the probability of coupled gating within channel clusters. Interestingly, BIN1 clusters also served as sites for sarcoplasmic reticulum (SR) anchoring and stabilization. Accordingly, BIN1-expressing cells had more CaV1.2-ryanodine receptor junctions than control cells. This was associated with larger [Ca2+]itransients during excitation-contraction coupling. Our data support the view that BIN1 is a key regulator of T-tubule formation and CaV1.2 channel delivery. By studying the role of BIN1 during the differentiation of hESC-CMs, we show that BIN1 is also important for CaV1.2 channel clustering, junctional SR organization, and the establishment of EC coupling.'],
#   'documentIdentifiers': ['PMID:30353632',
#    'DOI:10.1002/stem.2927',
#    'MANUSCRIPT:NIHMS993100'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'Stem Cells',
#   'source': 'Stem Cells',
#   'authors': ['Ana De La Mata',
#    'Sendoa Tajada',
#    'Samantha O’Dwyer',
#    'Collin Matsumoto',
#    'Rose E. Dixon',
#    'Nirmala Hariharan',
#    'Claudia M. Moreno',
#    'L. Fernando Santana'],
#   'language': ['EN'],
#   'date': 1580571707008,
#   '_version_': 1624644053385609216},
#  {'id': 'PMCID:PMC5568777',
#   'title': ['Leading Causes of Fatal and Nonfatal Unintentional Injury for Children and Teens and the Role of Lifestyle Clinicians'],
#   'abstract': ['About 1 in 5 child deaths is a result of unintentional injury. The leading causes of unintentional injury death vary by age. This report provides national fatal and nonfatal data for children and teens by age, sex, and race/ethnicity. Prevention strategies for the most common causes are highlighted. Opportunities for lifestyle clinicians to effectively guide their patients and their parents are discussed.'],
#   'documentIdentifiers': ['PMID:28845146',
#    'DOI:10.1177/1559827617696297',
#    'MANUSCRIPT:HHSPA895126'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'Am J Lifestyle Med',
#   'source': 'Am J Lifestyle Med',
#   'authors': ['Ann Dellinger', 'Julie Gilchrist'],
#   'language': ['EN'],
#   'date': 1580559577896,
#   '_version_': 1624631335091961856},
#  {'id': 'PMCID:PMC6317725',
#   'title': ['Functional Plasticity in Somatosensory Cortex Supports Motor Learning\nby Observing'],
#   'abstract': ['[No abstract available]'],
#   'documentIdentifiers': ['PMID:30513324',
#    'DOI:10.1016/j.cub.2018.11.043',
#    'MANUSCRIPT:NIHMS998370'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'Curr. Biol.',
#   'source': 'Curr. Biol.',
#   'authors': ['Heather R. McGregor',
#    'Joshua G.A. Cashaback',
#    'Paul L. Gribble'],
#   'language': ['EN'],
#   'date': 1578066021026,
#   '_version_': 1624643963233239040},
#  {'id': 'PMCID:PMC6218268',
#   'title': ['LRRK1 Regulation of Actin Assembly in Osteoclasts Involves Serine 5 Phosphorylation of L-Plastin'],
#   'abstract': ['Mice with disruption of Lrrk1 and patients with non-functional mutant Lrrk1 exhibited severe osteopetrosis phenotypes because of osteoclast cytoskeletal dysfunction. To understand how Lrrk1 regulates osteoclast function by modulating cytoskeleton rearrangement, we examined proteins that are differentially phosphorylated in wild type mice and Lrrk1 deficient osteoclasts by metal affinity purification coupled LC/MS analyses. One of the candidates that we have identified by LC/MS is L-plastin, an actin bundling protein. We found that phosphorylation of L-plastin at serine (Ser) residues 5 was only present in wild type osteoclasts but not in Lrrk1 deficient cells. Western blot analyses with antibodies specific for Ser5 phosphorylated L-plastin confirmed the reduced L-plastin Ser5 phosphorylation in Lrrk1 knockout (KO) osteoclasts. Micro-CT analyses revealed that trabecular bone volume of the distal femur was increased by 27% in the 16–21-week-old L-plastin KO females as compared to the wild type control mice. The ratio of bone volume to tissue volume and connectivity density were increased by 44% and 47% (both P<0.05), respectively, in L-plastin KO mice. Our data suggest that targeted disruption of L-plastin increases trabecular bone volume, and phosphorylation of Ser5 in L-plastin in the Lrrk1 signaling pathway may in part contribute to actin assembly in mature osteoclasts.'],
#   'documentIdentifiers': ['PMID:30136304',
#    'DOI:10.1002/jcb.27377',
#    'MANUSCRIPT:NIHMS980536'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'J. Cell. Biochem.',
#   'source': 'J. Cell. Biochem.',
#   'authors': ['Mingjue Si',
#    'Helen Goodluck',
#    'Canjun Zeng',
#    'Songqin Pan',
#    'Elizabeth M. Todd',
#    'Sharon Celeste Morley',
#    'Xuezhong Qin',
#    'Subburaman Mohan',
#    'Weirong Xing'],
#   'language': ['EN'],
#   'date': 1577888502292,
#   '_version_': 1624639015276773376},
#  {'id': 'PMCID:PMC6268205',
#   'title': ['Mitonuclear epistasis, genotype-by-environment interactions and personalized genomics of complex traits in Drosophila'],
#   'abstract': ['Mitochondrial function requires the coordinated expression of dozens of gene products from the mitochondrial genome and hundreds from the nuclear genomes. The systems that emerge from these interactions convert the food we eat and the oxygen we breathe into energy for life, while regulating a wide range of other cellular processes. These facts beg the question of whether the gene-by-gene interactions (GxG) that enable mitochondrial function are distinct from the gene- by-environment interactions (GxE) that fuel mitochondrial activity. We examine this question using a Drosophila model of mitonuclear interactions in which experimental combinations of mtDNA and nuclear chromosomes generate pairs of mitonuclear genotypes to test for epistatic interactions (GxG). These mitonuclear genotypes are then exposed to altered dietary or oxygen environments to test for GxE interactions. We use development time to assess dietary effects, and genome wide RNAseq analyses to assess hypoxic effects on transcription, which can be partitioned in to mito, nuclear, and environmental (GxGxE) contributions to these complex traits. We find that mitonuclear epistasis is universal, and that dietary and hypoxic treatments alter the epistatic interactions. We further show that the transcriptional response to alternative mitonuclear interactions has significant overlap with the transcriptional response to alternative oxygen environments. Gene coexpression analyses suggest that these shared genes are more central in networks of gene interactions, implying some functional overlap between epistasis and genotype by environment interactions. These results are discussed in the context of evolutionary fitness, the genetic basis of complex traits, and the challenge of achieving precision in personalized medicine.'],
#   'documentIdentifiers': ['PMID:30394643',
#    'DOI:10.1002/iub.1954',
#    'MANUSCRIPT:NIHMS993176'],
#   'docType': ['PMC_FULLTEXT'],
#   'journal': 'IUBMB Life',
#   'source': 'IUBMB Life',
#   'authors': ['David M. Rand',
#    'Jim A. Mossman',
#    'Lei Zhu',
#    'Leann M. Biancani',
#    'Jennifer Y. Ge'],
#   'language': ['EN'],
#   'date': 1577888172659,
#   '_version_': 1624638669631520768}]

# %%
fetchDocumentAndRenderHTML('PMCID:PMC6319626', 'PMC_2019')
# Out:
# <body><h1>2,3,7,8-Tetrachlorodibenzo-p-dioxin enhances CCl4-induced hepatotoxicity in an aryl hydrocarbon receptor-dependent manner</h1><div data-id="aa19a811-08c6-43ba-be01-7da3a5cab354" class="sec"><h2>Abstract</h2><div data-id="e0f3e675-9ed2-427c-b7f3-415fd49d0091" class="sec"><p data-id="c2a7fe9c-451c-4220-8f29-643ae45e2e01" class="par">Cytochrome P4502E1 (CYP2E1) is involved in the biotransformation of several low molecular weight chemicals and plays an important role in the metabolic activation of carcinogens and hepatotoxins such as CCl 4 . Induction of CYP2E1 is exerted mainly at posttranscriptional levels through mRNA and protein stabilization, and there is little evidence of xenobiotic induction at the transcriptional level. Previously, we reported microarray analysis data suggesting a decrease in Cyp2e1 gene expression on Ahr -null livers when compared to wild-type mouse livers. The goal of the present study was to determine whether 2,3,7,8-tetrachlorodibenzo-p-dioxin (TCDD) increased mouse CYP2E1 levels in an AhR-dependent manner and the impact on CCl 4 -induced hepatotoxicity. TCDD treatment induced CYP2E1 mRNA and protein levels in mouse liver, and this effect was aryl hydrocarbon receptor (AhR)-dependent. Moreover, TCDD pre-treatment increased the CCl 4 -induced alanine aminotransferase (ALT) activity, the extent of CCl 4 -induced necrosis, and the number of sinusoidal cells in wild-type animals, while this potentiating effect was not observed in Ahr -null mice. In conclusion, this study revealed that TCDD, probably in an AhR-dependent manner, exacerbated CCl 4 -induced hepatotoxicity through induction of CYP2E1. </p></div></div><div data-id="9f3faf85-f36d-4436-b4a2-09dcd54c62a9" class="sec"><h3>Introduction</h3><p data-id="cc49cd6f-bed4-4591-8619-9d4158dfc4db" class="par">Cytochrome P4502E1 (CYP2E1) is involved in the biotransformation of several low molecular weight chemicals, many of which are organic solvents. This enzyme has been extensively studied because it plays an important role in the metabolic activation of precarcinogens, such as benzene and nitrosamines, as well as hepatotoxins, including carbon tetrachloride (CCl 4 ) and acetaminophen ( &lt;Wong et al., 1998&gt; ; &lt;Cheung et al., 2005&gt; ). Several endogenous CYP2E1 substrates also have been identified, including lipid peroxidation products, ketones, and fatty acids; and it was suggested that they play a role in gluconeogenesis ( &lt;Lieber, 2004&gt; ). CYP2E1 is constitutively expressed in the liver and several other tissues. CYP2E1 induction by various chemicals is exerted mainly at post-transcriptional level, and there is little evidence of xenobiotic induction at the transcriptional level. Mouse, rat, and human CYP2E1 transcription is mainly under the control of hepatocyte nuclear factor 1&alpha; (HNF1&alpha;) ( &lt;Cheung et al., 2003&gt; ). Other studies have shown that mouse CYP2E1 expression is also regulated by &beta;-catenin ( &lt;Sekine et al., 2006&gt; ) and leptine ( &lt;Leclercq et al., 2000&gt; ). On the other hand, aryl hydrocarbon receptor (AhR) ligands such as 3-methylcholanthrene, &beta;-naphthoflavone and pyridine increase CYP2E1 transcription and activity ( &lt;Anderson and Angel, 1980&gt; ; &lt;Mostafa et al., 1981&gt; ; &lt;Kim et al., 1988&gt; ; &lt;Sinal et al., 1999&gt; ; &lt;Iba et al., 2000&gt; ), suggesting a role for this transcription factor in the regulation of CYP2E1 expression. More recently, it was reported that TCDD induce CYP2E1 expression in H9c2 cells ( &lt;Zordoky and El-Kadi, 2010&gt; ). AhR, a member of the basic helix-loop-helix-Per-Arnt-Sim (bHLH-PAS) transcription factor family, is a ligand-activated receptor that mediates the toxicity of environmental pollutants, such as 2,3,7,8-tetrachlorodibenzo-p-dioxin (TCDD) ( &lt;Okey et al., 1994&gt; ; &lt;Whitlock, 1999&gt; ). Upon binding to TCDD, AhR translocate to the nucleus, dimerises with AhR nuclear-translocator protein (ARNT), binds dioxin-responsiv ...

# %%
fetchDocument('PMCID:PMC6319626', 'PMC_2019')
# Out:
# {'provenance': {'license': None,
#   'version': '1.0',
#   'source': 'file:/home/bio/groupshare/library/PMC/manuscript_2019/006/PMC006XXXXXX.xml.tar.gz',
#   'date': 1549370953740,
#   'collection': 'PMC_2019',
#   'comments': None},
#  'documentElement': {'metaElement': {'bibliographic': {'documentAbstract': {'abstractSections': [{'paragraphs': [{'sentences': None,
#          'structureElements': [{'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'Cytochrome P4502E1 (CYP2E1) is involved in the biotransformation of several low molecular weight chemicals and plays an important role in the metabolic activation of carcinogens and hepatotoxins such as CCl',
#             'uuid': 'dcd86d65-c171-4b39-be75-ec59424effa6',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '4',
#             'uuid': '4b0ad676-f270-43ae-8c9f-4f7b549ca6a6',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '. Induction of CYP2E1 is exerted mainly at posttranscriptional levels through mRNA and protein stabilization, and there is little evidence of xenobiotic induction at the transcriptional level. Previously, we reported microarray analysis data suggesting a decrease in',
#             'uuid': '8afa3a9a-accd-4df7-a206-0904f92bda94',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'Cyp2e1',
#             'uuid': '022467b1-25f0-4c83-b0ae-6775fcf1c7b3',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'gene expression on',
#             'uuid': 'bc92543e-9135-4283-91b1-3465ba55dd3a',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'Ahr',
#             'uuid': 'c62b9a94-89ed-47e0-81fb-b728a767283c',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '-null livers when compared to wild-type mouse livers.',
#             'uuid': '148d8b89-4760-44f5-ace8-80d93049ccbb',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'The goal of the present study was to determine whether 2,3,7,8-tetrachlorodibenzo-p-dioxin (TCDD) increased mouse CYP2E1 levels in an AhR-dependent manner and the impact on CCl',
#             'uuid': 'c7d7b2af-42bb-4705-9cfd-e92bca0765c1',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '4',
#             'uuid': 'e601d63f-d169-4d18-bda9-68f2a483b05c',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '-induced hepatotoxicity.',
#             'uuid': 'a67ed275-c259-4f0e-9cb0-75dbfa817676',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'TCDD treatment induced CYP2E1 mRNA and protein levels in mouse liver, and this effect was aryl hydrocarbon receptor (AhR)-dependent.',
#             'uuid': 'bb5ddb7b-5faf-46dd-9350-11c1c0499e36',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'Moreover, TCDD pre-treatment increased the CCl',
#             'uuid': '196f9360-2328-4249-9976-cadb28746cfc',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '4',
#             'uuid': '86643ff3-8508-447a-b4b7-4b2771877d74',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '-induced alanine aminotransferase (ALT) activity, the extent of CCl',
#             'uuid': '39d2489d-1603-4647-8451-5a189eb590aa',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '4',
#             'uuid': '5defeb81-b1a8-432d-a59f-352e23e2f458',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '-induced necrosis, and the number of sinusoidal cells in wild-type animals, while this potentiating effect was not observed in',
#             'uuid': 'a744da5b-3c54-464a-aab4-cacde1754933',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'Ahr',
#             'uuid': 'e166a22f-e0a3-4459-97f4-401c116bcd1f',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '-null mice.',
#             'uuid': '10a57d83-0908-42e0-97fb-fca46032bbc2',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': 'In conclusion, this study revealed that TCDD, probably in an AhR-dependent manner, exacerbated CCl',
#             'uuid': '34cbc8d7-c59b-494f-9efb-c14fa21f73ea',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '4',
#             'uuid': '96ee8e40-925e-4aa1-a2e6-f2be83c9d857',
#             'annotations': None},
#            'sentence': None,
#            'list': None},
#           {'captionedBox': None,
#            'code': None,
#            'dataTable': None,
#            'figure': None,
#            'formula': None,
#            'imageContent': None,
#            'outline': None,
#            'quotation': None,
#            'table': None,
#            'textElement': {'text': '-induced hepatotoxicity through induction of CYP2E1.',
#             'uuid': 'a8b50149-4c4f-4faf-a5af-5a9a808a90b4',
#             'annotations': None},
#            'sentence': None,
#            'list': None}]}],
#        'depth': 0,
#        'rhetorical': None,
#        'title': None}]},
#     'authors': [{'author': {'surname': {'text': 'Mejia-Garcia',
#         'uuid': '57f7d7e9-66db-4e1f-a314-d8b0182b08ee',
#         'annotations': None},
#        'forename': {'text': 'Alejandro',
#         'uuid': '44315576-b7e9-4dcf-931c-13b376157cf2',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None},
#      {'author': {'surname': {'text': 'Sanchez-Ocampo',
#         'uuid': 'e77eedd1-b775-4ed0-ac41-488112b4452a',
#         'annotations': None},
#        'forename': {'text': 'Esmeralda M.',
#         'uuid': '4ef2784d-29ba-484b-abff-bf225e7ba57d',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None},
#      {'author': {'surname': {'text': 'Galindo-Gomez',
#         'uuid': '2efafc8b-834e-444c-b4c1-033ca2614132',
#         'annotations': None},
#        'forename': {'text': 'Silvia',
#         'uuid': 'b206ea83-8725-44a5-ac58-83d26062433a',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None},
#      {'author': {'surname': {'text': 'Shibayama',
#         'uuid': 'cfc585bd-eea2-4d5c-8346-56fa47278279',
#         'annotations': None},
#        'forename': {'text': 'Mineko',
#         'uuid': '1f7d2183-de75-434b-904c-6abec6c91003',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None},
#      {'author': {'surname': {'text': 'Reyes-Hernandez',
#         'uuid': 'c65305f3-84fb-4262-9526-6e5633369de6',
#         'annotations': None},
#        'forename': {'text': 'Octavio',
#         'uuid': 'b54606a5-e501-4202-ae66-5acc5f0aba71',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None},
#      {'author': {'surname': {'text': 'Guzman-Leon',
#         'uuid': '8e843ecf-d764-48c6-a707-b63017561e5e',
#         'annotations': None},
#        'forename': {'text': 'Simon',
#         'uuid': '874b469a-0244-4c64-9e72-ed888d0ab202',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None},
#      {'author': {'surname': {'text': 'Gonzalez',
#         'uuid': '485e90aa-d1d2-459b-9521-632767b4c903',
#         'annotations': None},
#        'forename': {'text': 'Frank J.',
#         'uuid': '11b49410-288a-4ab3-94d7-aca0085eb956',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None},
#      {'author': {'surname': {'text': 'Elizondo',
#         'uuid': '9279bec7-17ac-498a-8173-0ca5ba1d6c60',
#         'annotations': None},
#        'forename': {'text': 'Guillermo',
#         'uuid': '172796ac-b766-42eb-8fac-099b05a69b18',
#         'annotations': None},
#        'affiliation': None,
#        'degree': None},
#       'organization': None}],
#     'pubDate': {'day': 4, 'month': 1, 'year': 2019, 'date': 1549274965360},
#     'licenses': [{'licenseName': {'text': None,
#        'uuid': '9dd37b45-17a2-41d8-8bb2-46d90640ac6e',
#        'annotations': None},
#       'licenseURL': None,
#       'validUntil': None,
#       'rightsHolder': None}],
#     'title': {'titleText': {'text': '2,3,7,8-Tetrachlorodibenzo-p-dioxin enhances CCl4-induced hepatotoxicity in an aryl hydrocarbon receptor-dependent manner',
#       'uuid': 'a8d6e761-f7cf-4e7a-8a77-2a98443211a7',
#       'annotations': None},
#      'subtitleText': None},
#     'language': {'text': 'EN',
#      'uuid': '815130c6-6c95-4a5e-859d-b456440a7a70',
#      'annotations': None},
#     'source': {'text': 'Xenobiotica',
#      'uuid': '95595460-36b8-413f-bdff-434c98cacf3c',
#      'annotations': None},
#     'issns': [{'text': '0049-8254',
#       'uuid': 'cd4f5c4c-4a83-47c5-b650-480c55de4be7',
#       'annotations': None}],
#     'publicationTypes': None},
#    'bibliography': {'references': {'R1': {'authors': [{'author': {'surname': {'text': 'Anderson',
#           'uuid': '12eed76f-d0a4-47c1-9f57-862d55a7cf6a',
#           'annotations': None},
#          'forename': {'text': 'LM',
#           'uuid': '92d61dc0-41f7-4ecb-aaeb-56cfc583b58c',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Angel',
#           'uuid': '6232a46d-a1c9-402a-a629-2ddd130001f0',
#           'annotations': None},
#          'forename': {'text': 'M',
#           'uuid': 'bea9b428-fdd1-4de5-bae1-f17d560e3fff',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1980, 'date': 315482965360},
#       'publicationIds': [{'text': 'pmid:6772190',
#         'uuid': '09d8ec81-786f-4e0a-bab1-7952f36c019e',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Biochem Pharmacol;29:1375-1383',
#        'uuid': '107e2719-99bc-4cab-97b7-b2d4e9fc41e1',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '80929e8a-014e-4bb0-a99b-ea685680979e',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Induction of dimethylnitrosamine demethylase activity in mouse liver by polychlorinated biphenyls and 3-methylcholanthrene',
#         'uuid': 'f4eb3572-fdab-4eaf-b494-34cabadcfb74',
#         'annotations': None},
#        'subtitleText': None}},
#      'R2': {'authors': [{'author': {'surname': {'text': 'Braeuning',
#           'uuid': 'd7688853-ddf0-4358-8510-a696f2a1e086',
#           'annotations': None},
#          'forename': {'text': 'A',
#           'uuid': '61b22075-3b37-492a-b36d-bc053635e23b',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Köhle',
#           'uuid': 'ba90c093-2b3a-4c80-aa76-23fe1eb87821',
#           'annotations': None},
#          'forename': {'text': 'C',
#           'uuid': '1bdb20e6-6d72-44aa-9ae4-1757cd5b2560',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Buchmann',
#           'uuid': 'ab076432-3e8b-46c2-9ba9-6a2f27b276f3',
#           'annotations': None},
#          'forename': {'text': 'A',
#           'uuid': '6b91c61a-cb9f-4caa-bb91-925664e6d830',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Schwarz',
#           'uuid': '3274b078-f2e2-42df-9e3f-c6aff9c49970',
#           'annotations': None},
#          'forename': {'text': 'M',
#           'uuid': 'c5cf0470-4549-49d1-9d04-8b82095ec3b7',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 2011, 'date': 1293790165360},
#       'publicationIds': [{'text': 'pmid:21498875',
#         'uuid': 'ece91679-9958-4324-9293-fd7a86d927f0',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Toxicol Sci;122:16-25',
#        'uuid': '3da432b4-427e-4f23-b49f-880201e63cbc',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': 'cb2b5f59-e368-4321-a7cb-555d2cbb95cc',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Coordinate regulation of cytochrome P450 1a1 expression in mouse liver by the aryl hydrocarbon receptor and the beta-catenin pathway',
#         'uuid': '9fd06f7b-6e30-4fb6-be4c-02ea818f105a',
#         'annotations': None},
#        'subtitleText': None}},
#      'R3': {'authors': [{'author': {'surname': {'text': 'Cheadle',
#           'uuid': '89a8fc2f-ba1c-4f07-a888-603094e45fda',
#           'annotations': None},
#          'forename': {'text': 'C',
#           'uuid': 'af59d561-dcd3-457b-a13c-04a5b64cc611',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Vawter',
#           'uuid': '449873f9-098a-4946-abe5-18aa758db003',
#           'annotations': None},
#          'forename': {'text': 'MP',
#           'uuid': 'a3c6b851-550d-4ebf-acb4-d1d5b4a04550',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Freed',
#           'uuid': '227578e1-0138-4888-bfe0-5e0707a07b9e',
#           'annotations': None},
#          'forename': {'text': 'WJ',
#           'uuid': '6eb75a49-2584-4e4d-8987-bcfb15bb7827',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Becker',
#           'uuid': '60d60e14-f972-4fa2-9c44-2b74cc07b110',
#           'annotations': None},
#          'forename': {'text': 'KG',
#           'uuid': '62889cfc-d537-4e8d-8b92-b9675b19002d',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 2003, 'date': 1041329365360},
#       'publicationIds': [{'text': 'pmid:12707371',
#         'uuid': '18ace381-0268-4cb9-8440-eb204f012ad2',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'J Mol Diagn;5:73-81',
#        'uuid': '02a2c186-6325-4daa-a1b4-966976823d21',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '415ac8f6-2f3c-4324-8396-3b743aa61e43',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Analysis of microarray data using Z score transformation',
#         'uuid': '53503924-2da4-4973-bada-30bcc67ebaf7',
#         'annotations': None},
#        'subtitleText': None}},
#      'R4': {'authors': [{'author': {'surname': {'text': 'Cheung',
#           'uuid': '86f25de7-a0d3-4681-8200-b9dfd40e57a4',
#           'annotations': None},
#          'forename': {'text': 'C',
#           'uuid': 'a4da4868-af25-42ae-8bb6-5a8baa04ab91',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Akiyama',
#           'uuid': '739ea13a-5011-48f5-ada8-29b204c1db07',
#           'annotations': None},
#          'forename': {'text': 'TE',
#           'uuid': '153b5b06-3ebd-44f9-85ab-33c30fbf7a18',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Kudo',
#           'uuid': '504c8cb3-54f4-4a00-a797-74818764c283',
#           'annotations': None},
#          'forename': {'text': 'G',
#           'uuid': 'eb308b74-c855-4a61-9607-a2418f122e61',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Gonzalez',
#           'uuid': 'df824309-ad4a-4fca-ac35-f377d856ba47',
#           'annotations': None},
#          'forename': {'text': 'FJ',
#           'uuid': '7addbe52-b2ad-4d14-9fdd-715dad8aca20',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 2003, 'date': 1041329365360},
#       'publicationIds': [{'text': 'pmid:14599559',
#         'uuid': '19d1b81e-aa21-4331-8292-af0e1567f44e',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Biochem Pharmacol;66:2011-2020',
#        'uuid': 'a8b9b68b-1b1d-43f1-a388-d3d2ab15dad3',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '3f83aed7-500c-442f-863b-33596324f558',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Hepatic expression of cytochrome P450s in hepatocyte nuclear factor 1-alpha (HNF1alpha)-deficient mice',
#         'uuid': 'a82afbc1-68cb-4121-bfa0-7be3f2d7b97a',
#         'annotations': None},
#        'subtitleText': None}},
#      'R5': {'authors': [{'author': {'surname': {'text': 'Cheung',
#           'uuid': 'de70645d-dfbb-43e0-a9c2-51ec497081df',
#           'annotations': None},
#          'forename': {'text': 'C',
#           'uuid': 'f81addfb-aad4-4510-9e5f-0aaceb44e01b',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Yu',
#           'uuid': '15df930a-807c-4135-8273-6188164b4bac',
#           'annotations': None},
#          'forename': {'text': 'AM',
#           'uuid': '64cab55a-c98f-419b-beb3-11f96c35b1f6',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Ward',
#           'uuid': 'ca07e040-3638-4137-8e67-5e1b372f16f4',
#           'annotations': None},
#          'forename': {'text': 'JM',
#           'uuid': '025c49e0-fce9-4161-8edf-9d91afcbe650',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Krausz',
#           'uuid': 'aa291acc-7f3a-42ea-9b1b-dd584b7330bb',
#           'annotations': None},
#          'forename': {'text': 'KW',
#           'uuid': '0fd3f0ed-d6d9-43ef-af01-6fb5a2f8f4c5',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Akiyama',
#           'uuid': 'd0d9d485-bb57-48d7-959b-48a2e010a0b2',
#           'annotations': None},
#          'forename': {'text': 'TE',
#           'uuid': '43bad269-12d2-4bbb-9cb8-189119827d0e',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Feigenbaum',
#           'uuid': '08d8a91c-de20-4077-b69d-e28c71861549',
#           'annotations': None},
#          'forename': {'text': 'L',
#           'uuid': '255b7428-793d-4a7d-9ff2-3bac6d9400a8',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Gonzalez',
#           'uuid': '988f74cc-c970-4b26-85b2-4b52b5db75a7',
#           'annotations': None},
#          'forename': {'text': 'FJ',
#           'uuid': 'bd154a62-e5fb-406c-9ac7-6a7857549294',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 2005, 'date': 1104487765361},
#       'publicationIds': [{'text': 'pmid:15576447',
#         'uuid': 'b45b230a-cd5d-48b1-82f8-900a6497a293',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Drug Metab Dispos;33:449-457',
#        'uuid': '166be3ad-30c9-4297-9cb9-c7fddaa382e8',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '5e5f4cc0-7f2e-444b-9094-f05a9d51b15a',
#        'annotations': None},
#       'title': {'titleText': {'text': 'The cyp2e1-humanized transgenic mouse: role of cyp2e1 in acetaminophen hepatotoxicity',
#         'uuid': '4affe4ec-489b-4972-abfa-3584e67727f5',
#         'annotations': None},
#        'subtitleText': None}},
#      'R6': {'authors': [{'author': {'surname': {'text': 'Cronkite',
#           'uuid': 'e1d578db-8c8f-4db3-b373-9cf017993189',
#           'annotations': None},
#          'forename': {'text': 'EP',
#           'uuid': 'b0f69a05-e287-4847-b5e5-929e2b99804a',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Bullis',
#           'uuid': 'b9a2cb8e-50f4-4956-899b-f23c8e48a238',
#           'annotations': None},
#          'forename': {'text': 'J',
#           'uuid': '55a96a45-6571-4b36-8038-cf7ee60bc127',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Inoue',
#           'uuid': '6005e2d4-b2e9-49b9-a5ff-e478687bf09b',
#           'annotations': None},
#          'forename': {'text': 'T',
#           'uuid': '5bbcb237-577e-4e06-968b-d9743c9777a8',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Drew',
#           'uuid': '339a67ab-fe0c-45da-af11-03d3e2677204',
#           'annotations': None},
#          'forename': {'text': 'RT',
#           'uuid': '4a67c539-1622-437b-8efc-3685928dfd69',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1984, 'date': 441713365361},
#       'publicationIds': [{'text': 'pmid:6474468',
#         'uuid': '16c8407d-bce0-4425-99a0-322550626552',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Toxicol Appl Pharmacol;75:358-361',
#        'uuid': 'b047042a-d879-48c8-b3c8-03adc3ff7fca',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '19a4b6c4-453f-4c08-ae33-11a0d3851b1d',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Benzene inhalation produces leukemia in mice',
#         'uuid': '054f9442-8d66-4b07-bc4b-a79be3ecf668',
#         'annotations': None},
#        'subtitleText': None}},
#      'R7': {'authors': [{'author': {'surname': {'text': 'De Matteis',
#           'uuid': '42c1e6ad-8dcb-47fa-b655-d8e6f66d3c6b',
#           'annotations': None},
#          'forename': {'text': 'F',
#           'uuid': '52bc2a40-a8d5-4ce5-8c6a-9cad9fec5d92',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Dawson',
#           'uuid': '8b01ec0e-c5dc-4606-bc7e-d4009f902726',
#           'annotations': None},
#          'forename': {'text': 'SJ',
#           'uuid': 'ebe4f233-1fd6-4263-b262-c01f8e75c6ab',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Boobis',
#           'uuid': 'fbecf4a7-efd2-4a24-b532-8717cccd4f4f',
#           'annotations': None},
#          'forename': {'text': 'AR',
#           'uuid': '0a4559e5-7347-48ed-a28c-01edf34f4ef2',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Comoglio',
#           'uuid': '0a4c92d5-7253-49d4-b943-9fe76432f398',
#           'annotations': None},
#          'forename': {'text': 'A',
#           'uuid': 'c18a08a7-fa06-4757-acd7-d81bc2a6e53b',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1991, 'date': 662638165361},
#       'publicationIds': [{'text': 'pmid:1944239',
#         'uuid': '407b5d70-65f7-48d1-9ba8-bb4166d32bde',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Mol Pharmacol;40:686-691',
#        'uuid': 'f4b1834a-9050-4e85-be8b-e9f0717e7334',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '8df3ecff-f37d-4778-966c-5cf7faa7e5e8',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Inducible bilirubin-degrading system of rat liver microsomes: role of cytochrome P450IA1',
#         'uuid': 'a7466280-d9ee-4c77-9199-48f7b9007c2c',
#         'annotations': None},
#        'subtitleText': None}},
#      'R8': {'authors': [{'author': {'surname': {'text': 'Elizondo',
#           'uuid': '219153db-bc70-4a9e-8db6-c17c6cd2b187',
#           'annotations': None},
#          'forename': {'text': 'G',
#           'uuid': '42a26117-27f5-48e6-be14-6bce73713d72',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Fernandez-Salguero',
#           'uuid': 'a5aade17-ad36-4736-a52b-faec98376d40',
#           'annotations': None},
#          'forename': {'text': 'P',
#           'uuid': 'd74fe79b-4920-4815-9551-468729f50e73',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Sheikh',
#           'uuid': '640c6529-a719-497d-8004-21f3fefaef2d',
#           'annotations': None},
#          'forename': {'text': 'MS',
#           'uuid': 'f03cd0e2-3e2b-4f99-befa-7ef75e79b3fd',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Kim',
#           'uuid': '1c0e98af-2016-489c-8794-4ea83743bcf5',
#           'annotations': None},
#          'forename': {'text': 'GY',
#           'uuid': '134fd088-cd55-444a-aaf2-b15665433a05',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Fornace',
#           'uuid': '35165402-de3e-4cae-8b66-7b32339fa91f',
#           'annotations': None},
#          'forename': {'text': 'AJ',
#           'uuid': 'f38cd258-98ea-44be-82a7-bd8f8d50c42f',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Lee',
#           'uuid': 'b68b865d-79db-4390-9a8c-6e0692f4eccf',
#           'annotations': None},
#          'forename': {'text': 'KS',
#           'uuid': 'cc08f6ae-ecac-4516-83b4-0c28b3f5711c',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Gonzalez',
#           'uuid': '14654d47-674c-44f2-8636-59e3ac499e5d',
#           'annotations': None},
#          'forename': {'text': 'FJ',
#           'uuid': '740520e8-bf69-40c1-8cb9-ad53a202f73b',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 2000, 'date': 946634965361},
#       'publicationIds': [{'text': 'pmid:10779392',
#         'uuid': '4cb6976d-7318-42f8-9a4b-bff83ea48cf1',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Mol Pharmacol;57:1056-1063',
#        'uuid': 'd638d950-6874-42bc-be48-ff3efe8bd53c',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '2138d7c4-ba39-4858-b959-51172ffa56e3',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Altered cell cycle control at the G(2)/M phases in aryl hydrocarbon receptor-null embryo fibroblast',
#         'uuid': '2b5669b4-16bb-41d1-a1e8-058b7a38a35a',
#         'annotations': None},
#        'subtitleText': None}},
#      'R9': {'authors': [{'author': {'surname': {'text': 'Farris',
#           'uuid': '751cc410-0da0-4110-a220-d8233fb6dcef',
#           'annotations': None},
#          'forename': {'text': 'GM',
#           'uuid': 'd483e2b8-c1fa-47b4-be51-00dd53f88448',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Robinson',
#           'uuid': 'c204c06d-b9ff-4aad-ab38-d1cf399a9c4b',
#           'annotations': None},
#          'forename': {'text': 'SN',
#           'uuid': '8513341c-5a93-4468-af85-a1e374ee3201',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Gaido',
#           'uuid': '2e327f7d-0594-4960-ab8c-035ead9ef334',
#           'annotations': None},
#          'forename': {'text': 'KW',
#           'uuid': '8a976068-3bdb-4164-8072-251b9f59be31',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Wong',
#           'uuid': '4b0598fd-37a1-4c49-abd7-f24d2f9fdcbb',
#           'annotations': None},
#          'forename': {'text': 'BA',
#           'uuid': '2304cdf4-bf03-45c9-a721-6550d3ca6c7c',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Wong',
#           'uuid': '73d8dd00-c077-41a6-b7ac-f6fc6cb877f7',
#           'annotations': None},
#          'forename': {'text': 'VA',
#           'uuid': 'a9aa00f1-6115-4e85-8326-a8be07292727',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Hahn',
#           'uuid': 'b33f698c-839a-49ab-81ae-9c1714e4f86c',
#           'annotations': None},
#          'forename': {'text': 'WP',
#           'uuid': 'de79d220-21de-4078-be3c-2afd055afd86',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Shah',
#           'uuid': 'eb668c3f-f0e5-4ce5-8bb5-4a2def88b421',
#           'annotations': None},
#          'forename': {'text': 'RS',
#           'uuid': '9171c4be-36c9-40f0-aa0b-f572240a948d',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1997, 'date': 852026965361},
#       'publicationIds': [{'text': 'pmid:9143481',
#         'uuid': '2f9e246a-5445-43d3-9773-f1a60532b3dc',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Fundam Appl Toxicol;36:119-129',
#        'uuid': '93c023b1-4c9c-4ac3-b5aa-79f73dbf88d3',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '01c36fed-c6b1-40a7-9616-ae79498ea3d4',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Benzene-induced hematotoxicity and bone marrow compensation in B6C3F1 mice',
#         'uuid': '6c3386d1-4d83-40d5-a765-44647d926d65',
#         'annotations': None},
#        'subtitleText': None}},
#      'R10': {'authors': [{'author': {'surname': {'text': 'Fernandez-Salguero',
#           'uuid': '338f3668-2e49-4876-aded-f19d8b2056dd',
#           'annotations': None},
#          'forename': {'text': 'P',
#           'uuid': '1dafc1b5-7290-47f6-ab58-5299222c4e16',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Pineau',
#           'uuid': '719686c8-879e-408e-80e7-ef9e048c01cc',
#           'annotations': None},
#          'forename': {'text': 'T',
#           'uuid': 'f8c74d52-4aa5-4d11-8f93-84b8fadea16b',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Hilbert',
#           'uuid': '0a9b4a5e-2a28-48e1-b82d-1fa892ff8b4d',
#           'annotations': None},
#          'forename': {'text': 'DM',
#           'uuid': 'f292c2f8-439b-43c7-929b-3ab0ea65321e',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'McPhail',
#           'uuid': 'eed97a41-fe8d-42b1-8e19-f8d77c3fa69a',
#           'annotations': None},
#          'forename': {'text': 'T',
#           'uuid': '47b44910-7c7e-4642-8454-8b1a3ec680f7',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Lee',
#           'uuid': 'c08021ef-d55b-4aa3-a6e6-3beac16dfab6',
#           'annotations': None},
#          'forename': {'text': 'SS',
#           'uuid': '4c2bfd4c-07ef-4e6f-b7f3-534a4b0356df',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Kimura',
#           'uuid': '63284433-616d-4e15-8553-ec2d97e4eca8',
#           'annotations': None},
#          'forename': {'text': 'S',
#           'uuid': 'a1efbaa5-b12a-4c71-a07f-0456d61c84dd',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Nebert',
#           'uuid': 'd08213ab-bccc-4a75-ade6-9e758079b760',
#           'annotations': None},
#          'forename': {'text': 'DW',
#           'uuid': '46c77d91-20db-44eb-adde-dc57f786d389',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Rudikoff',
#           'uuid': '1ac8bc54-feca-4aab-9b62-25b44a3be944',
#           'annotations': None},
#          'forename': {'text': 'S',
#           'uuid': '618137e1-19ee-48cc-937e-fd0960143017',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Ward',
#           'uuid': '6f8d7ce5-d421-474b-ab75-4d257e5c36b0',
#           'annotations': None},
#          'forename': {'text': 'JM',
#           'uuid': '3feda7e2-437d-460a-9efd-6bc143d08d66',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Gonzalez',
#           'uuid': '7d7c488a-438c-4571-8b67-eeb0583b54e7',
#           'annotations': None},
#          'forename': {'text': 'FJ',
#           'uuid': 'b47e0b2a-3d80-4bdd-aa2f-f2d4a7a2eba8',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1995, 'date': 788868565361},
#       'publicationIds': [{'text': 'pmid:7732381',
#         'uuid': 'c1861428-ef6d-4d82-999e-4744f3eaa479',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Science;268:722-726',
#        'uuid': '8972be29-feaf-4b42-bfc4-8001ae5391c0',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': 'bef0de84-3941-4030-82ba-69175c6c0905',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Immune system impairment and hepatic fibrosis in mice lacking the dioxin-binding Ah receptor',
#         'uuid': '6fd647de-9721-4a0c-8f13-8a473738689d',
#         'annotations': None},
#        'subtitleText': None}},
#      'R11': {'authors': [{'author': {'surname': {'text': 'Fernandez-Salguero',
#           'uuid': 'b55f82c8-0f6c-4781-97bd-8a3c39d9be34',
#           'annotations': None},
#          'forename': {'text': 'PM',
#           'uuid': '8a6eecb2-cb3f-4993-820a-863fab7a5c40',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Hilbert',
#           'uuid': '44b93edc-2a16-46a2-8c67-e2ee7d2c1edf',
#           'annotations': None},
#          'forename': {'text': 'DM',
#           'uuid': '3690a82c-71ca-4d2e-90a9-3e6d3afde82e',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Rudikoff',
#           'uuid': '49cab1e1-5b0c-4247-80fa-ca09c2ece1ee',
#           'annotations': None},
#          'forename': {'text': 'S',
#           'uuid': 'aac37825-7bcc-414b-8f2f-22b5431cd177',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Ward',
#           'uuid': 'e6ab34bd-8b09-48fa-a252-d4ee05c98aaf',
#           'annotations': None},
#          'forename': {'text': 'JM',
#           'uuid': '9ccee3cf-8767-4587-81f2-faf24fed0a7e',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Gonzalez',
#           'uuid': 'e5c01a08-57fe-4c6e-867d-a7bb60e622e6',
#           'annotations': None},
#          'forename': {'text': 'FJ',
#           'uuid': '3294d6bf-9632-44f4-a866-13f575ce7eb5',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1996, 'date': 820404565361},
#       'publicationIds': [{'text': 'pmid:8806883',
#         'uuid': '822966c0-1b6c-4caf-bdbf-f0e568a02392',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Toxicol Appl Pharmacol;140:173-179',
#        'uuid': '4c174f14-bb31-4b77-bbe8-3c557c64e2b2',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '0c351f75-ce37-4de3-a3ee-d3a56e1f2be0',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Aryl-hydrocarbon receptor-deficient mice are resistant to 2,3,7,8-tetrachlorodibenzo-p-dioxin-induced toxicity',
#         'uuid': '50b61e76-d0cb-4118-8bd0-5878b2ef7f30',
#         'annotations': None},
#        'subtitleText': None}},
#      'R12': {'authors': [{'author': {'surname': {'text': 'Gaido',
#           'uuid': '5d1bebf2-de7a-4a37-a13f-7a4b461c33f3',
#           'annotations': None},
#          'forename': {'text': 'KW',
#           'uuid': '380dc9db-ccb2-43ef-946a-7850cbe4f482',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Maness',
#           'uuid': 'd6a71c50-a895-4229-9bfe-6df57d7c42b1',
#           'annotations': None},
#          'forename': {'text': 'SC',
#           'uuid': '582813d0-90ad-4260-87c2-7e86bbce21d2',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1995, 'date': 788868565361},
#       'publicationIds': [{'text': 'pmid:7597708',
#         'uuid': '82adcd28-6a28-4441-b099-653fba0f1ae7',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'Toxicol Appl Pharmacol;133:34-42',
#        'uuid': '797d83e9-4477-47ac-80a1-e383a4069044',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '24d53aad-9002-47c9-8c0c-1562f36e14e1',
#        'annotations': None},
#       'title': {'titleText': {'text': 'Post-transcriptional stabilization of urokinase plasminogen activator mRNA by 2,3,7,8-tetrachlorodibenzo-p-dioxin in a human keratinocyte cell line',
#         'uuid': '6157d6cf-1329-4d0e-b112-492fd0f4d4f2',
#         'annotations': None},
#        'subtitleText': None}},
#      'R13': {'authors': [{'author': {'surname': {'text': 'Gaido',
#           'uuid': '959ac398-53ee-4ea8-b488-74d8d3cb52a5',
#           'annotations': None},
#          'forename': {'text': 'KW',
#           'uuid': '4e4def62-a47e-42b4-bd54-8ae2712cdf76',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Maness',
#           'uuid': '197d407f-48f1-4063-bef0-a3141fe93ef7',
#           'annotations': None},
#          'forename': {'text': 'SC',
#           'uuid': 'b6a088bb-a162-4fc9-b802-5fc764be45e3',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Leonard',
#           'uuid': 'f83c1639-3ecd-42a1-8b32-59c333a8117f',
#           'annotations': None},
#          'forename': {'text': 'LS',
#           'uuid': 'cee41e8f-c243-491e-bb42-a62663ffb374',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None},
#        {'author': {'surname': {'text': 'Greenlee',
#           'uuid': 'b0ca3b71-705d-40f4-a782-ab4961677ade',
#           'annotations': None},
#          'forename': {'text': 'WF',
#           'uuid': '0f2231ea-935e-4aa6-81af-3269e760840f',
#           'annotations': None},
#          'affiliation': None,
#          'degree': None},
#         'organization': None}],
#       'date': {'day': 0, 'month': 0, 'year': 1992, 'date': 694174165361},
#       'publicationIds': [{'text': 'pmid:1447203',
#         'uuid': '4c7e2c52-cb7a-463b-87a2-4d6ee7f9ad78',
#         'annotations': None}],
#       'language': None,
#       'referenceSource': {'text': 'J Biol Chem;267:24591-24595',
#        'uuid': 'b67e902e-872f-4710-8a57-f2a00b95b5d7',
#        'annotations': None},
#       'publicationType': {'text': 'journal',
#        'uuid': '136eb3d4-283e-4e84-acd4-34fcbc5e2f4d',
#        'annotations': None},
#       'title': {'titleText': {'text': '2,3,7,8-Tetrachlorodibenzo-p-dioxin-dependent regulation of transforming growth factors-alpha and -beta 2 expression in a human keratinocyte cell line involves both transcriptional and post-transcriptional control',
#         'uuid': '96318044-7e90-4a53-a8cc-375dffbc2a6e',
#         'annotations': None},
#        'subtitleText': None}},
#      'R14': {'authors': [{'author': {'surname': {'text': 'Gekakis',
#           'uuid': '678dbeec-1847-4ffa-bd5d-3df206384efa',
#           'annotations': None},
#          'forename': {'text': 'N',
# ...
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': '<Yoon et al., 2002>',
#           'uuid': '7946d9a0-add9-4f71-b46d-dd283721008b',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': ') reported that',
#           'uuid': '4f7cba0d-39a7-4e57-baeb-c3a7071fc8f5',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': 'Ahr',
#           'uuid': '79147e47-05b7-41b4-8e27-6bffef6cf7d3',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': '-null mice are less susceptible to benzene toxicity than wild-type animals. Moreover, benzene treatment results in induction of CYP2E1 expression in wild-type mice, while no significant changes were observed in',
#           'uuid': '0583dbb9-4e5c-46f2-9581-6b07555effba',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': 'Ahr',
#           'uuid': '4e26e7cc-e0a2-4999-b3ae-02efb14e670d',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': '-null mouse livers.',
#           'uuid': '12c7f15c-9df5-45bd-87f9-9e08b33ffe7a',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': 'Evidence from other laboratories and the present results suggest that AhR activation induces CYP2E1 levels. However, it is not clear whether the underlying molecular mechanism is at the transcriptional or posttranscriptional level or both.',
#           'uuid': 'e8d6dd52-6ca5-472d-9e52-b334e5d9422e',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': 'In conclusion, the present study showed that TCDD, probably in an AhR-dependent manner, exacerbated CCl',
#           'uuid': '372b2840-788e-40b0-b3cf-195e14133ae1',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': '4',
#           'uuid': '6217c4ef-ed30-4200-b06e-8f9beb75e9a9',
#           'annotations': None},
#          'sentence': None,
#          'list': None},
#         {'captionedBox': None,
#          'code': None,
#          'dataTable': None,
#          'figure': None,
#          'formula': None,
#          'imageContent': None,
#          'outline': None,
#          'quotation': None,
#          'table': None,
#          'textElement': {'text': '-induced hepatotoxicity by inducing CYP2E1 levels. Future studies are necessary to elucidate the molecular mechanism whereby AhR mediates CYP2E1 induction.',
#           'uuid': 'afa9488e-797a-4dc3-b5e6-8bcdf5203e2e',
#           'annotations': None},
#          'sentence': None,
#          'list': None}]}],
#      'depth': 1,
#      'rhetorical': {'text': 'Discussion',
#       'uuid': '738907c7-9382-4cdc-a8d9-be2b364bf20a',
#       'annotations': None},
#      'title': {'text': 'Discussion',
#       'uuid': 'b4e5d557-394c-4ad2-87c6-63d3013a1750',
#       'annotations': None}}],
#    'docAbstract': None},
#   'frontMatter': {'titleText': {'text': '2,3,7,8-Tetrachlorodibenzo-p-dioxin enhances CCl4-induced hepatotoxicity in an aryl hydrocarbon receptor-dependent manner',
#     'uuid': 'a8d6e761-f7cf-4e7a-8a77-2a98443211a7',
#     'annotations': None},
#    'documentAbstract': {'abstractSections': [{'paragraphs': [{'sentences': None,
#         'structureElements': [{'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'Cytochrome P4502E1 (CYP2E1) is involved in the biotransformation of several low molecular weight chemicals and plays an important role in the metabolic activation of carcinogens and hepatotoxins such as CCl',
#            'uuid': 'dcd86d65-c171-4b39-be75-ec59424effa6',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '4',
#            'uuid': '4b0ad676-f270-43ae-8c9f-4f7b549ca6a6',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '. Induction of CYP2E1 is exerted mainly at posttranscriptional levels through mRNA and protein stabilization, and there is little evidence of xenobiotic induction at the transcriptional level. Previously, we reported microarray analysis data suggesting a decrease in',
#            'uuid': '8afa3a9a-accd-4df7-a206-0904f92bda94',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'Cyp2e1',
#            'uuid': '022467b1-25f0-4c83-b0ae-6775fcf1c7b3',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'gene expression on',
#            'uuid': 'bc92543e-9135-4283-91b1-3465ba55dd3a',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'Ahr',
#            'uuid': 'c62b9a94-89ed-47e0-81fb-b728a767283c',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '-null livers when compared to wild-type mouse livers.',
#            'uuid': '148d8b89-4760-44f5-ace8-80d93049ccbb',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'The goal of the present study was to determine whether 2,3,7,8-tetrachlorodibenzo-p-dioxin (TCDD) increased mouse CYP2E1 levels in an AhR-dependent manner and the impact on CCl',
#            'uuid': 'c7d7b2af-42bb-4705-9cfd-e92bca0765c1',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '4',
#            'uuid': 'e601d63f-d169-4d18-bda9-68f2a483b05c',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '-induced hepatotoxicity.',
#            'uuid': 'a67ed275-c259-4f0e-9cb0-75dbfa817676',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'TCDD treatment induced CYP2E1 mRNA and protein levels in mouse liver, and this effect was aryl hydrocarbon receptor (AhR)-dependent.',
#            'uuid': 'bb5ddb7b-5faf-46dd-9350-11c1c0499e36',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'Moreover, TCDD pre-treatment increased the CCl',
#            'uuid': '196f9360-2328-4249-9976-cadb28746cfc',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '4',
#            'uuid': '86643ff3-8508-447a-b4b7-4b2771877d74',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '-induced alanine aminotransferase (ALT) activity, the extent of CCl',
#            'uuid': '39d2489d-1603-4647-8451-5a189eb590aa',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '4',
#            'uuid': '5defeb81-b1a8-432d-a59f-352e23e2f458',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '-induced necrosis, and the number of sinusoidal cells in wild-type animals, while this potentiating effect was not observed in',
#            'uuid': 'a744da5b-3c54-464a-aab4-cacde1754933',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'Ahr',
#            'uuid': 'e166a22f-e0a3-4459-97f4-401c116bcd1f',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '-null mice.',
#            'uuid': '10a57d83-0908-42e0-97fb-fca46032bbc2',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': 'In conclusion, this study revealed that TCDD, probably in an AhR-dependent manner, exacerbated CCl',
#            'uuid': '34cbc8d7-c59b-494f-9efb-c14fa21f73ea',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '4',
#            'uuid': '96ee8e40-925e-4aa1-a2e6-f2be83c9d857',
#            'annotations': None},
#           'sentence': None,
#           'list': None},
#          {'captionedBox': None,
#           'code': None,
#           'dataTable': None,
#           'figure': None,
#           'formula': None,
#           'imageContent': None,
#           'outline': None,
#           'quotation': None,
#           'table': None,
#           'textElement': {'text': '-induced hepatotoxicity through induction of CYP2E1.',
#            'uuid': 'a8b50149-4c4f-4faf-a5af-5a9a808a90b4',
#            'annotations': None},
#           'sentence': None,
#           'list': None}]}],
#       'depth': 0,
#       'rhetorical': None,
#       'title': None}]}}},
#  'docType': 'PMC_FULLTEXT',
#  'originalMimeType': 'text/xml'}

# %%
data = pd.io.json.json_normalize(documents)
data
# Out:
#              _version_                                           abstract  \
# 0  1624645317434540032  [Diabetes is a leading cause of progressive mo...
# 1  1624645043740475392  [CRISPR-Cas9 and Cas12a (Cpf1) nucleases are t...
# 2  1624645050990329856  [Cachexia, the unintentional loss of body weig...
# 3  1624644678843367424  [Meniscus injuries are among the most common o...
# 4  1624644414228922368  [Perivascular accumulation of lymphocytes can ...
# 5  1624644053385609216  [Human embryonic stem cell-derived cardiomyocy...
# 6  1624631335091961856  [About 1 in 5 child deaths is a result of unin...
# 7  1624643963233239040                          [[No abstract available]]
# 8  1624639015276773376  [Mice with disruption of Lrrk1 and patients wi...
# 9  1624638669631520768  [Mitochondrial function requires the coordinat...
#
#                                              authors           date  \
# 0  [Victor T. ADEKANMBI, Olalekan A. UTHMAN, Sebh...  1583078512499
# 1  [Keunsub Lee, Yingxiao Zhang, Benjamin P. Klei...  1583078251468
# 2  [Justin P. Hardee, Brittany R. Counts, James A...  1580572658400
# 3  [Chathuraka T. Jayasuriya, John Twomey-Kozak, ...  1580572303495
# 4  [Alexander M. S. Barron, Julio C. Mantero, Jon...  1580572051111
# 5  [Ana De La Mata, Sendoa Tajada, Samantha O’Dwy...  1580571707008
# 6                   [Ann Dellinger, Julie Gilchrist]  1580559577896
# 7  [Heather R. McGregor, Joshua G.A. Cashaback, P...  1578066021026
# 8  [Mingjue Si, Helen Goodluck, Canjun Zeng, Song...  1577888502292
# 9  [David M. Rand, Jim A. Mossman, Lei Zhu, Leann...  1577888172659
#
#           docType                                documentIdentifiers  \
# 0  [PMC_FULLTEXT]  [PMID:30058263, DOI:10.1111/1753-0407.12829, M...
# 1  [PMC_FULLTEXT]  [PMID:29972722, DOI:10.1111/pbi.12982, MANUSCR...
# 2  [PMC_FULLTEXT]  [PMID:30627079, DOI:10.1177/1559827617725283, ...
# 3  [PMC_FULLTEXT]  [PMID:30358021, DOI:10.1002/stem.2923, MANUSCR...
# 4  [PMC_FULLTEXT]  [PMID:30510068, DOI:10.4049/jimmunol.1801209, ...
# 5  [PMC_FULLTEXT]  [PMID:30353632, DOI:10.1002/stem.2927, MANUSCR...
# 6  [PMC_FULLTEXT]  [PMID:28845146, DOI:10.1177/1559827617696297, ...
# 7  [PMC_FULLTEXT]  [PMID:30513324, DOI:10.1016/j.cub.2018.11.043,...
# 8  [PMC_FULLTEXT]  [PMID:30136304, DOI:10.1002/jcb.27377, MANUSCR...
# 9  [PMC_FULLTEXT]  [PMID:30394643, DOI:10.1002/iub.1954, MANUSCRI...
#
#                  id               journal language                source  \
# 0  PMCID:PMC6318039            J Diabetes     [EN]            J Diabetes
# 1  PMCID:PMC6320322  Plant Biotechnol. J.     [EN]  Plant Biotechnol. J.
# 2  PMCID:PMC6311610    Am J Lifestyle Med     [EN]    Am J Lifestyle Med
# 3  PMCID:PMC6312732            Stem Cells     [EN]            Stem Cells
# 4  PMCID:PMC6305793           J. Immunol.     [EN]           J. Immunol.
# 5  PMCID:PMC6312737            Stem Cells     [EN]            Stem Cells
# 6  PMCID:PMC5568777    Am J Lifestyle Med     [EN]    Am J Lifestyle Med
# 7  PMCID:PMC6317725           Curr. Biol.     [EN]           Curr. Biol.
# 8  PMCID:PMC6218268     J. Cell. Biochem.     [EN]     J. Cell. Biochem.
# 9  PMCID:PMC6268205            IUBMB Life     [EN]            IUBMB Life
#
#                                                title
# 0  [Epidemiology of prediabetes and diabetes in N...
# 1  [Activities and specificities of CRISPR-Cas9 a...
# 2  [Understanding the Role of Exercise in Cancer ...
# 3  [Human cartilage-derived progenitors resist te...
# 4  [Perivascular Adventitial Fibroblast Specializ...
# 5  [BIN1 induces the formation of T-tubules and a...
# 6  [Leading Causes of Fatal and Nonfatal Unintent...
# 7  [Functional Plasticity in Somatosensory Cortex...
# 8  [LRRK1 Regulation of Actin Assembly in Osteocl...
# 9  [Mitonuclear epistasis, genotype-by-environmen...

# %% [markdown]
# **to do**: filter documents for relevant sentences and display them ...
